# %%
import pandas as pd
import streamlit as st
import joblib

# modelo = joblib.load('modelo.joblib')

df_dados = pd.read_csv('dados.csv')

df_dados.drop('Unnamed: 0', axis=1, inplace= True)
df_dados.drop('price', axis=1, inplace= True)
atributos = df_dados.columns


x_numericos_keys = ['host_listings_count', 'latitude', 'longitude', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'extra_people', 'minimum_nights', 'month', 'year', 'n_amenities']

x_tf_keys = ['host_is_superhost', 'instant_bookable']

x_numericos = dict.fromkeys(x_numericos_keys,0)

x_tf = dict.fromkeys(x_tf_keys,0)

x_listas = {}

for col in df_dados:

    valor = df_dados.loc[0, col]

    if 'type' in col:

        objeto_tipo = str(col).split('_')[0]

        nome_tipo = str(col).split('_')[2]

        if f'{objeto_tipo}_type' in x_listas.keys():
        
            
            x_listas[f'{objeto_tipo}_type'].append(nome_tipo)
        else:
            x_listas[f'{objeto_tipo}_type'] = [nome_tipo]
    elif 'cancellation' in col:

        categoria = str(col).replace('cancellation_policy_', '')

        categoria = categoria#.title().replace('_', ' ')

        if 'cancellation_policy' in x_listas.keys():
    
            
            x_listas['cancellation_policy'].append(categoria)
        else:
            x_listas['cancellation_policy'] = [categoria]

    
print(x_listas)

print(x_numericos)

print(x_tf)
# Out:
# {'property_type': ['Apartment', 'Bed and breakfast', 'Condominium', 'Guest suite', 'Guesthouse', 'Hostel', 'House', 'Loft', 'Outros', 'Serviced apartment'], 'room_type': ['Entire home/apt', 'Hotel room', 'Private room', 'Shared room'], 'cancellation_policy': ['Flexible', 'Moderate', 'Strict', 'Strict 14 With Grace Period']}
# {'host_listings_count': 0, 'latitude': 0, 'longitude': 0, 'accommodates': 0, 'bathrooms': 0, 'bedrooms': 0, 'beds': 0, 'extra_people': 0, 'minimum_nights': 0, 'month': 0, 'year': 0, 'n_amenities': 0}
# {'host_is_superhost': 0, 'instant_bookable': 0}

# %%
for item in x_numericos:

    if item == 'latitude' or item == 'longitude':
        valor = st.number_input(f'{item}', step= 0.00001, value= 0.0, format='%.5f')
    elif item == 'extra_people':
        valor = st.number_input(f'{item}', step= 0.01, value= 0.0, format='%.2f')
    else:
        valor = st.number_input(f'{item}', step= 1, value= 0)
    
    x_numericos[item] = valor

for item in x_tf:
    valor = st.selectbox(f'{item}', ('Sim', 'Não'))

    x_tf[item] = 1 if valor == 'Sim' else 0

dicionario = {}

for item, lista_opcoes in x_listas.items():
    
    valor = st.selectbox(f'{item}', lista_opcoes)

    for opcao in lista_opcoes:
        coluna_dummy = f'{item}_{opcao}'
        
        if valor == opcao:

            dicionario[coluna_dummy] = 1
        else:
            dicionario[coluna_dummy] = 0


botao = st.button('Prever Valor do Imóvel')

if botao:
    dicionario.update(x_numericos)
    dicionario.update(x_tf)
    
    valores_x = pd.DataFrame(dicionario, index=[0])
    
    valores_x = valores_x[atributos]  # Reordenando colunas de maneira simplificada

    modelo = joblib.load('modelo.joblib')

    preco = modelo.predict(valores_x)

    st.write(f'O preço da diária do imóvel é estimado em: R$ {preco[0]}')
# Out:
# 2025-12-15 13:28:04.051 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.056 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.056 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.056 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.057 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2025-12-15 13:28:04.057 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.399
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Vinicius\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-12-15 13:28:04.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.403 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.403 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.403 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.403 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.404 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.404 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.405 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.405 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.405 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.406 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.406 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.406 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.408 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.408 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.408 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.409 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.409 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.409 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.414 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.415 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.415 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.415 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.415 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.416 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.416 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.417 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.417 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.417 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.417 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.418 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.418 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.418 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.418 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.419 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.419 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.420 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.420 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.420 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.420 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.420 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.421 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.421 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.422 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.422 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.422 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.423 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.423 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.425 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.425 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.425 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.426 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.426 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.426 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.427 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.427 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.428 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.428 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.429 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.429 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.429 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.430 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.430 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.431 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.431 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.431 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.434 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.434 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.434 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.434 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.435 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.435 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.436 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.436 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.436 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.437 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.437 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.437 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.438 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.438 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.438 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.439 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.439 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.439 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.439 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.440 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-15 13:28:04.440 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
